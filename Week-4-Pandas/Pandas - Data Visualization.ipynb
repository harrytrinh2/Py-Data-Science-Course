# %% [markdown]
# # Data Visualization

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
ls ml-20m
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 372F-3690
#
#  Directory of C:\Users\USER\Documents\Python for data science\Week-4-Pandas\ml-20m
#
# 10/17/2016  10:12 AM    <DIR>          .
# 10/17/2016  10:12 AM    <DIR>          ..
# 10/17/2016  09:41 AM       323,544,381 genome-scores.csv
# 10/17/2016  09:41 AM            18,103 genome-tags.csv
# 10/17/2016  09:50 AM           570,090 links.csv
# 03/31/2015  04:17 PM         1,397,542 movies.csv
# 03/31/2015  04:14 PM       533,444,411 ratings.csv
# 10/17/2016  10:21 AM            10,261 README.txt
# 03/31/2015  04:01 PM        16,603,996 tags.csv
#                7 File(s)    875,588,784 bytes
#                2 Dir(s)  19,816,595,456 bytes free

# %%
ratings=pd.read_csv("ml-20m/ratings.csv",sep=",")

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# 5              1      112     3.5  1094785740
# 6              1      151     4.0  1094785734
# 7              1      223     4.0  1112485573
# 8              1      253     4.0  1112484940
# 9              1      260     4.0  1112484826
# 10             1      293     4.0  1112484703
# 11             1      296     4.0  1112484767
# 12             1      318     4.0  1112484798
# 13             1      337     3.5  1094785709
# 14             1      367     3.5  1112485980
# 15             1      541     4.0  1112484603
# 16             1      589     3.5  1112485557
# 17             1      593     3.5  1112484661
# 18             1      653     3.0  1094785691
# ...

# %%
ratings.hist(column="rating",figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000007CBD9BEEF0>]], dtype=object)

# %% [markdown]
# #  Rút Trích

# %% [markdown]
# Số lượng Rating 4 có tỉ lệ nhiều nhất
#
# Tỉ lệ 4: lớn hơn 5.000.000
#
# Tỉ lệ 1:dưới 1.000.000

# %%
ratings.mean()
# Out:
# userId       6.904587e+04
# movieId      9.041567e+03
# rating       3.525529e+00
# timestamp    1.100918e+09
# dtype: float64

# %%
ratings.boxplot(column="rating", figsize=(15,20))

# %% [markdown]
# # Rút trích 2

# %% [markdown]
# Từ Boxplot ta có thể thấy độ giao động của mean()Trung bình 3.5
#
# Max =  5.0
#
# Min= 0.5
