# %% [markdown]
# # Descriptive Statistics

# %%
#let's look how the ratings are distriburted
# %matplotlib inline

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 372F-3690
#
#  Directory of C:\Users\USER\Documents\Python for data science\Week-4-Pandas
#
# 10/01/2017  03:30 PM            21,299  Data Cleaning.ipynb
# 10/02/2017  02:12 PM    <DIR>          .
# 10/02/2017  02:12 PM    <DIR>          ..
# 05/29/2017  11:04 AM             6,148 .DS_Store
# 10/01/2017  10:16 PM    <DIR>          .ipynb_checkpoints
# 05/26/2017  02:38 PM                 0 Icon_
# 05/29/2017  11:04 AM            33,379 Introduction to Pandas.ipynb
# 10/17/2016  10:12 AM    <DIR>          ml-20m
# 05/29/2017  11:04 AM    <DIR>          movielens
# 10/02/2017  02:12 PM            37,699 Pandas - Data Visualization.ipynb
# 10/02/2017  02:12 PM               882 Pandas - Descriptive Statistics .ipynb
# 10/01/2017  11:08 PM            32,603 pandas-  Frequent Data Operations.ipynb
# 09/25/2017  10:34 AM            54,086 Pandas 1 - Python for data science.ipynb
#                8 File(s)        186,096 bytes
# ...

# %%
import pandas as pd

# %%
ratings= pd.read_csv("ml-20m/ratings.csv",sep=",")

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
filter_rating= ratings["rating"]>3.0
ratings2=ratings[filter_rating]

# %% [markdown]
# # Revision of Groupby

# %%
ratings.groupby("timestamp").mean()
# Out:
#                    userId        movieId    rating
# timestamp
# 789652004    28507.000000    1176.000000  4.000000
# 789652009   131160.000000     382.333333  3.666667
# 822873600    95341.214286      30.285714  4.166667
# 823185196   124035.000000      52.500000  5.000000
# 823185197   124035.000000      48.500000  4.500000
# 823185198   124035.000000      60.000000  4.000000
# 823185200   124035.000000      18.500000  2.500000
# 823185203   124035.000000       5.500000  3.500000
# 823185204   124035.000000      11.000000  5.000000
# 823185205   124035.000000      34.000000  1.000000
# 823185206   124035.000000      35.000000  3.500000
# 823185207   124035.000000      46.000000  3.500000
# 823185212   124035.000000      60.500000  3.000000
# 823185213   124035.000000      63.000000  1.000000
# 823185214   124035.000000      61.500000  4.000000
# 823185215   124035.000000      46.000000  3.000000
# 823185216   124035.000000      46.000000  3.000000
# ...

# %%
ratings2.groupby("userId").agg(["mean","max","min","std"])
# Out:
#              movieId                                rating            \
#                 mean     max   min           std      mean  max  min
# userId
# 1        5376.428571    8636  1196   3135.682746  4.785714  5.0  4.5
# 2        1699.769231    3959    62   1322.373905  5.000000  5.0  5.0
# 3        1520.605263    5060    50    888.404294  5.000000  5.0  5.0
# 4         593.500000     733   454    197.282792  5.000000  5.0  5.0
# 5         678.815789    1393    11    374.142035  5.000000  5.0  5.0
# 6         132.571429     648     1    232.251916  5.000000  5.0  5.0
# 7        2166.238095    4963   260   1511.966795  5.000000  5.0  5.0
# 8         394.294118     648     3    203.860174  5.000000  5.0  5.0
# 9        2752.000000    4148   858   1345.645013  5.000000  5.0  5.0
# 10       1048.000000    1387   527    350.710707  5.000000  5.0  5.0
# 11      17032.441860   72641     1  21694.865550  4.802326  5.0  4.5
# ...

# %%
ratings2.groupby("rating").mean().plot(kind="bar")
